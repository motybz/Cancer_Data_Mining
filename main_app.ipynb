# %%
import os ,yaml,sys
from operator import itemgetter
from tools.import_data import *
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn import preprocessing
from sklearn.metrics import *
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn import feature_selection as fs

# consts
FILE_PATH = os.path.dirname(os.path.abspath("__file__"))
CONFIG_FILE = os.path.join(FILE_PATH, 'config.yml')
config = yaml.load(open(CONFIG_FILE, 'r'))
TRAIN_FILE = config['files']['train_set']
TEST_FILE = config['files']['test_set']
SCORING = config['score']

models = []

models.append(('LR', LogisticRegression()))
# models.append(('LDA', LinearDiscriminantAnalysis()))
# models.append(('KNN', KNeighborsClassifier()))
# models.append(('CART', DecisionTreeClassifier()))
# models.append(('NB', GaussianNB()))
# models.append(('SVM', SVC()))

# Classes
class DataSet:
    def __init__(self, X, Y, feature_list, threshold=None, ratio=None):
        self.X = X
        self.Y = Y
        self.feature_list = feature_list
        self.threshold = threshold
        self.ratio = ratio

class SkFModel:
    def __init__(self, name, sk_model):
        self.name = name
        self.skmodel = sk_model

class TrainedModel:
    def __init__(self, train_set=DataSet, my_sk_model=SkFModel, train_score=float ,test_set=DataSet):
        self.train_set = train_set
        self.test_set = test_set
        self.chosen_model = my_sk_model
        self.fited_model = None
        self.train_score = train_score
        self.test_score = None

    def test_the_model(self):
        self.test_score = test_the_data(self.test_set.X, self.test_set.Y, self.fited_model)
        return self.test_score

    # def set_chosen_model(self, name, fited_model):
    #     self.chosen_model = SkFModel(name, fited_model)

    def train_model(self):
        clf = self.chosen_model.skmodel
        clf.fit(self.train_set.X, self.train_set.Y)
        self.fited_model = clf



def pre_processing(X_set, Y_set):
    # Data pre processing
    # Encoding Categorial features and imputing NaN's
    # https://chrisalbon.com/machine_learning/preprocessing_structured_data/convert_pandas_categorical_column_into_integers_for_scikit-learn/
    # http://pbpython.com/categorical-encoding.html
    # https://datascience.stackexchange.com/questions/14069/mass-convert-categorical-columns-in-pandas-not-one-hot-encoding
    char_cols = X_set.dtypes.pipe(lambda x: x[x == 'object']).index
    if not char_cols.empty:
        label_mapping = {}
        for c in char_cols:
            original_X_set = X_set.copy()
            X_set[c], label_mapping[c] = pd.factorize(X_set[c])
    imp = preprocessing.Imputer(axis=0, verbose=1)
    imp = imp.fit(X_set)
    X_set = imp.transform(X_set)

    lb = preprocessing.LabelBinarizer()
    Y_set = lb.fit_transform(Y_set).ravel()

    print('Pre processing results: X_set-{} Y_set-{}'.format(X_set.shape, Y_set.shape))
    return X_set, Y_set

def get_models_CV_scores(X_train, Y_train, models):
    # Spot Check Algorithms with cross validation
    # evaluate each model in turn
    scores = []
    names = []
    results = []
    for name, model in models:
        kfold = model_selection.StratifiedKFold(n_splits=10, shuffle=True)
        try:
            cv_results = model_selection.cross_val_score(model, X_train, Y_train, cv=kfold, n_jobs=-1, scoring=SCORING)
        except ValueError as e:
            print('ValueError{}'.format(None))
        else:
            scores.append(cv_results)
            names.append(name)
            results.append({"model": SkFModel(name, model), "score": cv_results.mean()})
    # Compare Algorithms
    fig = plt.figure()
    fig.suptitle('Algorithm Comparison')
    ax = fig.add_subplot(111)
    plt.boxplot(scores)
    ax.set_xticklabels(names)
    plt.show()
    return results

def test_the_data(X_test, Y_test, fited_model):
    # Make predictions on test dataset
    scores = []
    scorer = get_scorer(SCORING)
    score = scorer(fited_model,X_test, Y_test)
    scores.append(score)
    return scores

def get_the_best(results):  # input - list of dict {"name":name,"score":score}
    m = max([k["score"] for k in results])
    i = [k["score"] for k in results].index(m)
    model = results[i]["model"]
    print('The best model for the given data is: {} with the score {}'.format(model.name, m))
    # print ('The best model for the given train (' + X_train.shape +') is: ' + name + 'with the score ' +m )
    return results[i]  # the max model (dict type)

if __name__ == "__main__":
    data_sets = []
    X_test = None
    X_train, Y_train, original_headers_train = load_dataset(TRAIN_FILE)
    data_sets.append({'X_train': X_train, 'Y_train': Y_train, 'original_headers_train': original_headers_train})
    print('Train data shape: ', X_train.shape)
    print('Train labels shape: ', Y_train.shape)
    X_train, Y_train = pre_processing(X_train, Y_train)
    if TEST_FILE:
        X_test, Y_test, original_headers_test = load_dataset(TEST_FILE)
        data_sets.append({'X_test': X_test, 'Y_test': Y_test, 'original_headers_test': original_headers_test})
        print('Test data shape: ', X_test.shape)
        print('Test labels shape: ', Y_test.shape)
        X_test, Y_test = pre_processing(X_test, Y_test)

    #create feature score list
    fs_scores = fs.mutual_info_classif(X_train,Y_train)
    feature_scores_list = []
    for i,score in enumerate(fs_scores):
        feature_scores_list.append({'feature_name':original_headers_train[i],'score':score})
    feature_scores_list.sort(key=itemgetter('score'),reverse=True)
    for feature in feature_scores_list:
        print (feature)

    # create the new datasets according to the feature selection ratio
    new_trains = []
    new_tests = []
    myrange = np.arange(0.01, 1, 0.01)
    for VTHRESH in myrange:
        sel = fs.SelectPercentile(score_func=fs.mutual_info_classif, percentile=VTHRESH * 100)
        sel.fit(X_train, Y_train)
        X_train_mod = sel.transform(X_train)
        if len(new_trains) >= 1:
            if new_trains[-1].ratio == X_train_mod.shape[-1] / X_train.shape[-1]:
                continue
        mask = sel.get_support()  # list of booleans
        new_features = []  # The list of your K best features
        for ans, feature in zip(mask, original_headers_train):
            if ans:
                new_features.append(feature)
        new_trains.append(DataSet(X_train_mod,Y_train,new_features, VTHRESH,
                                  X_train_mod.shape[-1] / X_train.shape[-1],)
                              )
        if TEST_FILE:
            new_test_features = []  # The list of your K best features
            for ans, feature in zip(mask, original_headers_test):
                if ans:
                    new_test_features.append(feature)
            X_test_mod = sel.transform(X_test)
            new_tests.append(DataSet(X_test_mod,Y_test,new_test_features, VTHRESH,
                                     X_test_mod.shape[-1] / X_test.shape[-1],)
                              )

    best_traind_models = []
    new_models = []
    for i, train_set in enumerate(new_trains):
        print("**Training Section** for: {} features ({})".format(str(train_set.X.shape[-1]),train_set.feature_list))
        train_results = get_models_CV_scores(train_set.X, train_set.Y, models)
        new_models.append({'train_set': train_set, 'train_resultes': train_results})
        if train_results:
            best_tr = get_the_best(train_results)
        best_traind_models.append(TrainedModel(train_set,best_tr['model'],best_tr['score']))
        if new_tests:
            best_traind_models[-1].test_set = new_tests[i]


        # best_tr_results.append({"model":best_tr['model'],
        #                         "score":best_tr['score'],
        #                         "num_fetures":int(train_set.X.shape[-1]),
        #                         'features_names':train_set['features_name']})

        # for model in train_results:
        #     print(model['model'].name, model['score'])

    plt.plot([d.ratio for d in new_trains],
             [d.train_score for d in best_traind_models])
    plt.legend()
    plt.show()

    sorted_reasultes = sorted(best_traind_models,key=lambda x: x.train_score)
    for best in sorted_reasultes:
        print("The best model for {} fetures is {} with teht score: {} and the feturaes {}".format(len(best.train_set.feature_list),
                                                                                                   best.chosen_model.name,
                                                                                                   best.train_score,
                                                                                                   best.train_set.feature_list))
    # need to modify the test shape
    print("**Testing Section:**")
    for trained_model in best_traind_models:
        print('Testing {} on {} with the model {}'.format(trained_model.train_set.X.shape,
                                                          trained_model.test_set.X.shape,
                                                          trained_model.chosen_model.name)
              )
        trained_model.train_model()
        trained_model.test_the_model()
        print ('Score - {}'.format(trained_model.test_score))
# Out:
# Train data shape:  (398, 20)
# Train labels shape:  (398,)
# Pre processing results: X_set-(398, 20) Y_set-(398,)
# Test data shape:  (776, 20)
# Test labels shape:  (776,)
# Pre processing results: X_set-(776, 20) Y_set-(776,)
# {'feature_name': 'WEIGHT', 'score': 0.13172368847960425}
# {'feature_name': 'SYM_CHEST_PAIN', 'score': 0.10210095568540356}
# {'feature_name': 'SYM_SLEEP_DISRUPTED', 'score': 0.067564605715889181}
# {'feature_name': 'AGE', 'score': 0.063301057145227269}
# {'feature_name': 'WAIST_CIRCUMFERENCE', 'score': 0.058804329180397907}
# {'feature_name': 'SEX', 'score': 0.057856554085453871}
# {'feature_name': 'SYM_TAKING_STOMACH_MEDS', 'score': 0.036593519936845231}
# {'feature_name': 'SYM_BURNING_CHEST', 'score': 0.028163809395721717}
# {'feature_name': 'PREFERRED_DRINK', 'score': 0.026533761886201379}
# {'feature_name': 'SYM_SORE_THROAT', 'score': 0.024282109785361161}
# {'feature_name': 'HEIGHT', 'score': 0.018578387985602962}
# {'feature_name': 'SYM_YRS_SINCE_ACID_TASTE_START', 'score': 0.018440760595223038}
# {'feature_name': 'SMK_AGE_STARTED', 'score': 0.016555823527388158}
# {'feature_name': 'SYM_ACID_TASTE', 'score': 0.01584498484213781}
# {'feature_name': 'ALC_UNITS_PER_WEEK', 'score': 0.01443347384370175}
# {'feature_name': 'ALC_UNITS_PER_WEEK_AGED_30', 'score': 0.0027617424483528108}
# {'feature_name': 'EDUCATION_LEVEL', 'score': 0.0}
# {'feature_name': 'SMK_EVER_SMOKED', 'score': 0.0}
# {'feature_name': 'SMK_AGE_SMOKING_STOPPED', 'score': 0.0}
# {'feature_name': 'ALC_DRINK_HEAVILY', 'score': 0.0}
# **Training Section** for: 1 features (['WEIGHT'])
# The best model for the given data is: LR with the score 0.6591315789473684
# **Training Section** for: 2 features (['WEIGHT', 'SYM_CHEST_PAIN'])
# The best model for the given data is: LR with the score 0.7256052631578948
# **Training Section** for: 3 features (['SEX', 'WEIGHT', 'SYM_CHEST_PAIN'])
# The best model for the given data is: LR with the score 0.7579210526315789
# **Training Section** for: 4 features (['AGE', 'WEIGHT', 'SYM_BURNING_CHEST', 'SYM_TAKING_STOMACH_MEDS'])
# The best model for the given data is: LR with the score 0.7690986842105263
# **Training Section** for: 5 features (['SEX', 'WEIGHT', 'WAIST_CIRCUMFERENCE', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST'])
# The best model for the given data is: LR with the score 0.7563157894736842
# **Training Section** for: 6 features (['SEX', 'WEIGHT', 'WAIST_CIRCUMFERENCE', 'SYM_CHEST_PAIN', 'SYM_YRS_SINCE_ACID_TASTE_START', 'SYM_TAKING_STOMACH_MEDS'])
# The best model for the given data is: LR with the score 0.8129473684210525
# **Training Section** for: 7 features (['AGE', 'SEX', 'WEIGHT', 'WAIST_CIRCUMFERENCE', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST', 'SYM_SORE_THROAT'])
# The best model for the given data is: LR with the score 0.7697236842105264
# **Training Section** for: 8 features (['AGE', 'SEX', 'HEIGHT', 'WEIGHT', 'SMK_AGE_SMOKING_STOPPED', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST', 'SYM_SORE_THROAT'])
# The best model for the given data is: LR with the score 0.7743947368421054
# **Training Section** for: 9 features (['SEX', 'WEIGHT', 'WAIST_CIRCUMFERENCE', 'SMK_AGE_STARTED', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST', 'SYM_SLEEP_DISRUPTED', 'SYM_YRS_SINCE_ACID_TASTE_START', 'SYM_TAKING_STOMACH_MEDS'])
# The best model for the given data is: LR with the score 0.8110657894736842
# **Training Section** for: 10 features (['AGE', 'SEX', 'WEIGHT', 'PREFERRED_DRINK', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST', 'SYM_SORE_THROAT', 'SYM_SLEEP_DISRUPTED', 'SYM_YRS_SINCE_ACID_TASTE_START', 'SYM_TAKING_STOMACH_MEDS'])
# The best model for the given data is: LR with the score 0.8242105263157894
# **Training Section** for: 11 features (['AGE', 'SEX', 'HEIGHT', 'WEIGHT', 'WAIST_CIRCUMFERENCE', 'EDUCATION_LEVEL', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST', 'SYM_SORE_THROAT', 'SYM_YRS_SINCE_ACID_TASTE_START', 'SYM_TAKING_STOMACH_MEDS'])
# The best model for the given data is: LR with the score 0.8188815789473682
# **Training Section** for: 12 features (['AGE', 'SEX', 'HEIGHT', 'WEIGHT', 'WAIST_CIRCUMFERENCE', 'ALC_UNITS_PER_WEEK_AGED_30', 'ALC_DRINK_HEAVILY', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST', 'SYM_SLEEP_DISRUPTED', 'SYM_YRS_SINCE_ACID_TASTE_START', 'SYM_TAKING_STOMACH_MEDS'])
# The best model for the given data is: LR with the score 0.8119342105263158
# **Training Section** for: 13 features (['AGE', 'SEX', 'HEIGHT', 'WEIGHT', 'WAIST_CIRCUMFERENCE', 'ALC_UNITS_PER_WEEK', 'ALC_UNITS_PER_WEEK_AGED_30', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST', 'SYM_SORE_THROAT', 'SYM_SLEEP_DISRUPTED', 'SYM_YRS_SINCE_ACID_TASTE_START', 'SYM_TAKING_STOMACH_MEDS'])
# The best model for the given data is: LR with the score 0.8129342105263158
# **Training Section** for: 14 features (['AGE', 'SEX', 'HEIGHT', 'WEIGHT', 'WAIST_CIRCUMFERENCE', 'EDUCATION_LEVEL', 'SMK_AGE_STARTED', 'PREFERRED_DRINK', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST', 'SYM_SORE_THROAT', 'SYM_SLEEP_DISRUPTED', 'SYM_YRS_SINCE_ACID_TASTE_START', 'SYM_TAKING_STOMACH_MEDS'])
# The best model for the given data is: LR with the score 0.8140526315789474
# **Training Section** for: 15 features (['AGE', 'SEX', 'HEIGHT', 'WEIGHT', 'WAIST_CIRCUMFERENCE', 'EDUCATION_LEVEL', 'SMK_AGE_SMOKING_STOPPED', 'ALC_UNITS_PER_WEEK', 'ALC_UNITS_PER_WEEK_AGED_30', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST', 'SYM_ACID_TASTE', 'SYM_SLEEP_DISRUPTED', 'SYM_YRS_SINCE_ACID_TASTE_START', 'SYM_TAKING_STOMACH_MEDS'])
# The best model for the given data is: LR with the score 0.8003552631578948
# **Training Section** for: 16 features (['AGE', 'SEX', 'HEIGHT', 'WEIGHT', 'WAIST_CIRCUMFERENCE', 'EDUCATION_LEVEL', 'SMK_AGE_STARTED', 'ALC_UNITS_PER_WEEK', 'ALC_UNITS_PER_WEEK_AGED_30', 'PREFERRED_DRINK', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST', 'SYM_ACID_TASTE', 'SYM_SLEEP_DISRUPTED', 'SYM_YRS_SINCE_ACID_TASTE_START', 'SYM_TAKING_STOMACH_MEDS'])
# The best model for the given data is: LR with the score 0.8076578947368421
# **Training Section** for: 17 features (['AGE', 'SEX', 'HEIGHT', 'WEIGHT', 'WAIST_CIRCUMFERENCE', 'SMK_EVER_SMOKED', 'SMK_AGE_STARTED', 'ALC_UNITS_PER_WEEK', 'ALC_DRINK_HEAVILY', 'PREFERRED_DRINK', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST', 'SYM_ACID_TASTE', 'SYM_SORE_THROAT', 'SYM_SLEEP_DISRUPTED', 'SYM_YRS_SINCE_ACID_TASTE_START', 'SYM_TAKING_STOMACH_MEDS'])
# The best model for the given data is: LR with the score 0.8095789473684212
# **Training Section** for: 18 features (['AGE', 'SEX', 'HEIGHT', 'WEIGHT', 'WAIST_CIRCUMFERENCE', 'EDUCATION_LEVEL', 'SMK_EVER_SMOKED', 'SMK_AGE_STARTED', 'SMK_AGE_SMOKING_STOPPED', 'ALC_UNITS_PER_WEEK', 'ALC_UNITS_PER_WEEK_AGED_30', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST', 'SYM_ACID_TASTE', 'SYM_SORE_THROAT', 'SYM_SLEEP_DISRUPTED', 'SYM_YRS_SINCE_ACID_TASTE_START', 'SYM_TAKING_STOMACH_MEDS'])
# The best model for the given data is: LR with the score 0.8172631578947369
# **Training Section** for: 19 features (['AGE', 'SEX', 'HEIGHT', 'WEIGHT', 'WAIST_CIRCUMFERENCE', 'EDUCATION_LEVEL', 'SMK_EVER_SMOKED', 'SMK_AGE_STARTED', 'SMK_AGE_SMOKING_STOPPED', 'ALC_UNITS_PER_WEEK', 'ALC_UNITS_PER_WEEK_AGED_30', 'ALC_DRINK_HEAVILY', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST', 'SYM_ACID_TASTE', 'SYM_SORE_THROAT', 'SYM_SLEEP_DISRUPTED', 'SYM_YRS_SINCE_ACID_TASTE_START', 'SYM_TAKING_STOMACH_MEDS'])
# The best model for the given data is: LR with the score 0.8122894736842105
# The best model for 1 fetures is LR with teht score: 0.6591315789473684 and the feturaes ['WEIGHT']
# The best model for 2 fetures is LR with teht score: 0.7256052631578948 and the feturaes ['WEIGHT', 'SYM_CHEST_PAIN']
# The best model for 5 fetures is LR with teht score: 0.7563157894736842 and the feturaes ['SEX', 'WEIGHT', 'WAIST_CIRCUMFERENCE', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST']
# The best model for 3 fetures is LR with teht score: 0.7579210526315789 and the feturaes ['SEX', 'WEIGHT', 'SYM_CHEST_PAIN']
# The best model for 4 fetures is LR with teht score: 0.7690986842105263 and the feturaes ['AGE', 'WEIGHT', 'SYM_BURNING_CHEST', 'SYM_TAKING_STOMACH_MEDS']
# The best model for 7 fetures is LR with teht score: 0.7697236842105264 and the feturaes ['AGE', 'SEX', 'WEIGHT', 'WAIST_CIRCUMFERENCE', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST', 'SYM_SORE_THROAT']
# The best model for 8 fetures is LR with teht score: 0.7743947368421054 and the feturaes ['AGE', 'SEX', 'HEIGHT', 'WEIGHT', 'SMK_AGE_SMOKING_STOPPED', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST', 'SYM_SORE_THROAT']
# The best model for 15 fetures is LR with teht score: 0.8003552631578948 and the feturaes ['AGE', 'SEX', 'HEIGHT', 'WEIGHT', 'WAIST_CIRCUMFERENCE', 'EDUCATION_LEVEL', 'SMK_AGE_SMOKING_STOPPED', 'ALC_UNITS_PER_WEEK', 'ALC_UNITS_PER_WEEK_AGED_30', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST', 'SYM_ACID_TASTE', 'SYM_SLEEP_DISRUPTED', 'SYM_YRS_SINCE_ACID_TASTE_START', 'SYM_TAKING_STOMACH_MEDS']
# The best model for 16 fetures is LR with teht score: 0.8076578947368421 and the feturaes ['AGE', 'SEX', 'HEIGHT', 'WEIGHT', 'WAIST_CIRCUMFERENCE', 'EDUCATION_LEVEL', 'SMK_AGE_STARTED', 'ALC_UNITS_PER_WEEK', 'ALC_UNITS_PER_WEEK_AGED_30', 'PREFERRED_DRINK', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST', 'SYM_ACID_TASTE', 'SYM_SLEEP_DISRUPTED', 'SYM_YRS_SINCE_ACID_TASTE_START', 'SYM_TAKING_STOMACH_MEDS']
# The best model for 17 fetures is LR with teht score: 0.8095789473684212 and the feturaes ['AGE', 'SEX', 'HEIGHT', 'WEIGHT', 'WAIST_CIRCUMFERENCE', 'SMK_EVER_SMOKED', 'SMK_AGE_STARTED', 'ALC_UNITS_PER_WEEK', 'ALC_DRINK_HEAVILY', 'PREFERRED_DRINK', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST', 'SYM_ACID_TASTE', 'SYM_SORE_THROAT', 'SYM_SLEEP_DISRUPTED', 'SYM_YRS_SINCE_ACID_TASTE_START', 'SYM_TAKING_STOMACH_MEDS']
# The best model for 9 fetures is LR with teht score: 0.8110657894736842 and the feturaes ['SEX', 'WEIGHT', 'WAIST_CIRCUMFERENCE', 'SMK_AGE_STARTED', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST', 'SYM_SLEEP_DISRUPTED', 'SYM_YRS_SINCE_ACID_TASTE_START', 'SYM_TAKING_STOMACH_MEDS']
# The best model for 12 fetures is LR with teht score: 0.8119342105263158 and the feturaes ['AGE', 'SEX', 'HEIGHT', 'WEIGHT', 'WAIST_CIRCUMFERENCE', 'ALC_UNITS_PER_WEEK_AGED_30', 'ALC_DRINK_HEAVILY', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST', 'SYM_SLEEP_DISRUPTED', 'SYM_YRS_SINCE_ACID_TASTE_START', 'SYM_TAKING_STOMACH_MEDS']
# The best model for 19 fetures is LR with teht score: 0.8122894736842105 and the feturaes ['AGE', 'SEX', 'HEIGHT', 'WEIGHT', 'WAIST_CIRCUMFERENCE', 'EDUCATION_LEVEL', 'SMK_EVER_SMOKED', 'SMK_AGE_STARTED', 'SMK_AGE_SMOKING_STOPPED', 'ALC_UNITS_PER_WEEK', 'ALC_UNITS_PER_WEEK_AGED_30', 'ALC_DRINK_HEAVILY', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST', 'SYM_ACID_TASTE', 'SYM_SORE_THROAT', 'SYM_SLEEP_DISRUPTED', 'SYM_YRS_SINCE_ACID_TASTE_START', 'SYM_TAKING_STOMACH_MEDS']
# The best model for 13 fetures is LR with teht score: 0.8129342105263158 and the feturaes ['AGE', 'SEX', 'HEIGHT', 'WEIGHT', 'WAIST_CIRCUMFERENCE', 'ALC_UNITS_PER_WEEK', 'ALC_UNITS_PER_WEEK_AGED_30', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST', 'SYM_SORE_THROAT', 'SYM_SLEEP_DISRUPTED', 'SYM_YRS_SINCE_ACID_TASTE_START', 'SYM_TAKING_STOMACH_MEDS']
# The best model for 6 fetures is LR with teht score: 0.8129473684210525 and the feturaes ['SEX', 'WEIGHT', 'WAIST_CIRCUMFERENCE', 'SYM_CHEST_PAIN', 'SYM_YRS_SINCE_ACID_TASTE_START', 'SYM_TAKING_STOMACH_MEDS']
# The best model for 14 fetures is LR with teht score: 0.8140526315789474 and the feturaes ['AGE', 'SEX', 'HEIGHT', 'WEIGHT', 'WAIST_CIRCUMFERENCE', 'EDUCATION_LEVEL', 'SMK_AGE_STARTED', 'PREFERRED_DRINK', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST', 'SYM_SORE_THROAT', 'SYM_SLEEP_DISRUPTED', 'SYM_YRS_SINCE_ACID_TASTE_START', 'SYM_TAKING_STOMACH_MEDS']
# The best model for 18 fetures is LR with teht score: 0.8172631578947369 and the feturaes ['AGE', 'SEX', 'HEIGHT', 'WEIGHT', 'WAIST_CIRCUMFERENCE', 'EDUCATION_LEVEL', 'SMK_EVER_SMOKED', 'SMK_AGE_STARTED', 'SMK_AGE_SMOKING_STOPPED', 'ALC_UNITS_PER_WEEK', 'ALC_UNITS_PER_WEEK_AGED_30', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST', 'SYM_ACID_TASTE', 'SYM_SORE_THROAT', 'SYM_SLEEP_DISRUPTED', 'SYM_YRS_SINCE_ACID_TASTE_START', 'SYM_TAKING_STOMACH_MEDS']
# The best model for 11 fetures is LR with teht score: 0.8188815789473682 and the feturaes ['AGE', 'SEX', 'HEIGHT', 'WEIGHT', 'WAIST_CIRCUMFERENCE', 'EDUCATION_LEVEL', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST', 'SYM_SORE_THROAT', 'SYM_YRS_SINCE_ACID_TASTE_START', 'SYM_TAKING_STOMACH_MEDS']
# The best model for 10 fetures is LR with teht score: 0.8242105263157894 and the feturaes ['AGE', 'SEX', 'WEIGHT', 'PREFERRED_DRINK', 'SYM_CHEST_PAIN', 'SYM_BURNING_CHEST', 'SYM_SORE_THROAT', 'SYM_SLEEP_DISRUPTED', 'SYM_YRS_SINCE_ACID_TASTE_START', 'SYM_TAKING_STOMACH_MEDS']
# **Testing Section:**
# Testing (398, 1) on (776, 1) with the model LR
# Score - [0.33990102639296182]
# Testing (398, 2) on (776, 2) with the model LR
# Score - [0.61842467008797652]
# Testing (398, 3) on (776, 3) with the model LR
# Score - [0.76936323924731176]
# Testing (398, 4) on (776, 4) with the model LR
# Score - [0.65277905058651031]
# Testing (398, 5) on (776, 5) with the model LR
# Score - [0.72254933406647104]
# Testing (398, 6) on (776, 6) with the model LR
# Score - [0.67020252932551327]
# Testing (398, 7) on (776, 7) with the model LR
# Score - [0.64522238514174002]
# Testing (398, 8) on (776, 8) with the model LR
# Score - [0.69483137829912012]
# Testing (398, 9) on (776, 9) with the model LR
# Score - [0.71804740957966762]
# Testing (398, 10) on (776, 10) with the model LR
# Score - [0.681619623655914]
# Testing (398, 11) on (776, 11) with the model LR
# Score - [0.61947091886608019]
# Testing (398, 12) on (776, 12) with the model LR
# Score - [0.63958638807429136]
# Testing (398, 13) on (776, 13) with the model LR
# Score - [0.6311705767350928]
# Testing (398, 14) on (776, 14) with the model LR
# Score - [0.61418621700879761]
# Testing (398, 15) on (776, 15) with the model LR
# Score - [0.65405822336265884]
# Testing (398, 16) on (776, 16) with the model LR
# Score - [0.60813019305962857]
# Testing (398, 17) on (776, 17) with the model LR
# Score - [0.63427877565982416]
# Testing (398, 18) on (776, 18) with the model LR
# Score - [0.67214228983382207]
# Testing (398, 19) on (776, 19) with the model LR
# Score - [0.65971713098729223]
